# %%
# %run resume_reader.py
# Out:
# LANDON WORK EXPERIENCE
# WINSLOW Computer Engineer
# Siemens Healthineers
# Computer Engineer
# 2018 - current Malvern, PA
# Redesigned signal-processing modules for Siemens medical
# l.winslow@email.com imaging firmware, cutting diagnostic system response time by
# 67%.
# (123) 456-7890
# Optimized FPGA resource allocation in Xilinx Vivado for ultrasound
# Malvern, PA
# hardware, reducing logic utilization by 89% without sacrificing
# LinkedIn
# throughput.
# Authored MATLAB analysis scripts that automated calibration data
# validation across 3 imaging product lines, accelerating processing
# cycles by 63%.
# EDUCATION
# Enforced branching and merge-request standards in Git that
# Bachelor of Science
# brought the team's codebase conflict rate down to under 2%.
# Electrical and Computer
# Engineering
# Systems Analyst
# Carnegie Mellon University
# PPG Industries
# 2008 - 2012
# 2015 - 2018 Pittsburgh, PA
# Pittsburgh, PA
# ...

# %%
# %run resume_reader_new.py
# Out:
#                                               Skills  Experience (Years)  \
# 0  Xilinx Vivado (FPGA Design), VHDL, MATLAB (Sig...                   6
# 1  Java (Android Development), Swift (iOS Develop...                   6
# 2  JavaScript (React, Node.js), Python (Django, s...                   3
# 3  Java (Android Development), Swift, (iOS Develo...                   4
# 4  McAfee Endpoint Security, Acronis True Image (...                   6
#
#   Education  Certifications  Projects Count
# 0      B.Sc             NaN               3
# 1      B.Sc             NaN               3
# 2      B.Sc             NaN               3
# 3      B.Sc             NaN               3
# 4      B.Sc             NaN               4
