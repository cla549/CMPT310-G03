# %%
# %run read_file.py
# Out:
# ['I', 'am', 'a', 'good', 'boy.']
# ['I', 'want', 'to', 'have', 'some', 'cookies.']
# ['Programming:', 'C,', 'C++,', 'Java,', 'Python']
# ['System:', 'Windows,', 'Linux']

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
# %run read_file.py test.docx output
# Out:
# .docx

# %%
# %run read_file.py test.pdf output
# Out:
# .pdf
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\CMPT310\CMPT310-G03\read_file.py:68
#      64     df.to_csv(output_directory / new_filename, index=False)
#      67 if __name__ == '__main__':
# ---> 68     main()
#
# File ~\CMPT310\CMPT310-G03\read_file.py:62, in main()
#      60 file_count = sum(1 for x in output_directory.iterdir() if x.is_file())
#      61 file_name_base = 'transformed_data.csv'
# ---> 62 temp_path = Path(file_name_base)
#      63 new_filename = f"{temp_path.stem}_{file_count + 1}{temp_path.suffix}"
#      64 df.to_csv(output_directory / new_filename, index=False)
#
# NameError: name 'Path' is not defined
